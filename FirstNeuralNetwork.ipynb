# %% [markdown]
# <a href="https://colab.research.google.com/github/palexey2006/Solidity-Projects/blob/main/FirstNeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# basic NeuralNetwork
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data() # uploading data to a vars from dataset
x_train = x_train.reshape(-1, 28 * 28).astype("float32") / 255 # -1 means that the model will leave the first column
# dividing by 255 to normalize values and to train faster
x_test = x_test.reshape(-1, 28 * 28).astype("float32") / 255
#same for x_test features(technically feature)

# Sequential API(Convinient, but not really flexible) means you enter 1 input and get 1 output

#initialize model wtih 512 neurons in the first hidden layer, 256 neurons in the second layer and 10 output layers(basically using softmax to limit the sum of
#all the predictions to 1). Also activation func for both layers is ReLu which works something like max(0, input)
model = keras.Sequential(
        [
        layers.Dense(512, activation="relu"),
        layers.Dense(256, activation="relu"),
        layers.Dense(10),
        ]
)



# creates a model with params such as numerical data,optimize this function with ADAM and learning rate equals 0.001
model.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics= ["accuracy"],
)
# train a model on a training set
model.fit(x_train, y_train, batch_size=32, epochs=5, verbose=2) #verbose 2 means that the progress bar will show for every epoch

#evaluate a model on a test set
model.evaluate(x_test,y_test, batch_size=32, verbose=2)
print(model.summary())
# Out:
# Epoch 1/5
# 1875/1875 - 16s - 8ms/step - accuracy: 0.9419 - loss: 0.1879
# Epoch 2/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9754 - loss: 0.0792
# Epoch 3/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9823 - loss: 0.0560
# Epoch 4/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9861 - loss: 0.0431
# Epoch 5/5
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9892 - loss: 0.0339
# 313/313 - 1s - 3ms/step - accuracy: 0.9775 - loss: 0.0820
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                     │ (32, 512)                   │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (32, 256)                   │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (32, 10)                    │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,607,456 (6.13 MB)
#  Trainable params: 535,818 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,071,638 (4.09 MB)
# None
